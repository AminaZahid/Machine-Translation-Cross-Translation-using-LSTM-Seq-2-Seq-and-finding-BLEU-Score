# %% [markdown]
# <a href="https://colab.research.google.com/github/AminaZahid/Machine-Translation-Cross-Translation-using-LSTM-Seq-2-Seq-and-finding-BLEU-Score/blob/main/MT_Cross_Translation_(LST_Seq_2_Seq_%26_BLEU_score).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.filterwarnings('ignore')
import string
import re
from unicodedata import normalize
import numpy as np
from keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.models import Sequential,load_model
from keras.layers import LSTM,Dense,Embedding,RepeatVector,TimeDistributed
from keras.callbacks import EarlyStopping
from keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing import sequence
from nltk.translate.bleu_score import corpus_bleu
import pandas as pd
from string import punctuation
import matplotlib.pyplot as plt
from IPython.display import Markdown, display
import keras
def printmd(string):
    # Print with Markdowns
    display(Markdown(string))

# %%
total_sentences = 10000
dataset = pd.read_csv("/content/drive/MyDrive/eng_-french.csv", nrows = total_sentences)

# What proportion of the sentences will be used for the test set
test_proportion = 0.1
train_test_threshold = int( (1-test_proportion) * total_sentences)

printmd(f'## {total_sentences} "parallel sentences" will be loaded (original sentence + its translation)')
printmd(f'## {train_test_threshold} "parallel sentences" will be used to train the model')
printmd(f'## {total_sentences-train_test_threshold} "parallel sentences" will be used to test the model')
# Out:
# ## 10000 "parallel sentences" will be loaded (original sentence + its translation)
# ## 9000 "parallel sentences" will be used to train the model
# ## 1000 "parallel sentences" will be used to test the model

# %%
import seaborn as sns

# %%
data_df=dataset.copy()

# %%
plt.figure(figsize=(12, 6))
plt.style.use('ggplot')
plt.subplot(1, 2, 1)
sns.distplot(data_df['English words/sentences'].str.split().apply(len))
plt.title('Distribution of English sentences length')
plt.xlabel('Length')

plt.style.use('ggplot')
plt.subplot(1, 2, 2)
sns.distplot(data_df['French words/sentences'].str.split().apply(len))
plt.title('Distribution of French sentences length')
plt.xlabel('Length')
plt.show()

# %%
# Shuffle the dataset
dataset = dataset.sample(frac=1, random_state=0)
dataset.iloc[1000:1010]
# Out:
#      English words/sentences French words/sentences
# 1554             Let me die.     Laisse-moi mourir.
# 2087            He's a slob.     C'est un flemmard.
# 5470          I have to try.  Il faut que j'essaie.
# 2363            I was naive.        Je fus crédule.
# 7570         He is bankrupt.    Il est en faillite.
# 6427          That's a fact.         C'est un fait.
# 1651             Talk to me!           Parlez-moi !
# 4164           Keep talking.   Continuez de parler.
# 1231             I broke it.        Je l'ai cassée.
# 9232         Tom is a judge.          Tom est juge.

# %%
def clean(string):
    # Clean the string
    string = string.replace("\u202f"," ") # Replace no-break space with space
    string = string.lower()

    # Delete the punctuation and the numbers
    for p in punctuation + "«»" + "0123456789":
        string = string.replace(p," ")

    string = re.sub('\s+',' ', string)
    string = string.strip()

    return string

# Clean the sentences
dataset["English words/sentences"] = dataset["English words/sentences"].apply(lambda x: clean(x))
dataset["French words/sentences"] = dataset["French words/sentences"].apply(lambda x: clean(x))

# Select one part of the dataset
dataset = dataset.values
dataset = dataset[:total_sentences]

# split into train/test
train, test = dataset[:train_test_threshold], dataset[train_test_threshold:]

# Define the name of the source and of the target
# This will be used in the outputs of this notebook
source_str, target_str = "French", "English"

# The index in the numpy array of the source and of the target
idx_src, idx_tar = 1, 0

# %%
# Display the result after cleaning
pd.DataFrame(dataset[1000:1010])
# Out:
#                 0                     1
# 0      let me die     laisse moi mourir
# 1     he s a slob     c est un flemmard
# 2   i have to try  il faut que j essaie
# 3     i was naive        je fus crédule
# 4  he is bankrupt    il est en faillite
# 5   that s a fact         c est un fait
# 6      talk to me            parlez moi
# 7    keep talking   continuez de parler
# 8      i broke it        je l ai cassée
# 9  tom is a judge          tom est juge

# %%
def create_tokenizer(lines):
    # fit a tokenizer
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(lines)
    return tokenizer

def max_len(lines):
    # max sentence length
    return max(len(line.split()) for line in lines)

def encode_sequences(tokenizer, length, lines):
    # encode and pad sequences
    X = tokenizer.texts_to_sequences(lines) # integer encode sequences
    X = pad_sequences(X, maxlen=length, padding='post') # pad sequences with 0 values
    return X

def encode_output(sequences, vocab_size):
    # one hot encode target sequence
    ylist = list()
    for sequence in sequences:
        encoded = to_categorical(sequence, num_classes=vocab_size)
        ylist.append(encoded)
    y = np.array(ylist)
    y = y.reshape(sequences.shape[0], sequences.shape[1], vocab_size)
    return y

# Prepare target tokenizer
tar_tokenizer = create_tokenizer(dataset[:, idx_tar])
tar_vocab_size = len(tar_tokenizer.word_index) + 1
tar_length = max_len(dataset[:, idx_tar])
printmd(f'\nTarget ({target_str}) Vocabulary Size: {tar_vocab_size}')
printmd(f'Target ({target_str}) Max Length: {tar_length}')

# Prepare source tokenizer
src_tokenizer = create_tokenizer(dataset[:, idx_src])
src_vocab_size = len(src_tokenizer.word_index) + 1
src_length = max_len(dataset[:, idx_src])
printmd(f'\nSource ({source_str}) Vocabulary Size: {src_vocab_size}')
printmd(f'Source ({source_str}) Max Length: {src_length}\n')

# Prepare training data
trainX = encode_sequences(src_tokenizer, src_length, train[:, idx_src])
trainY = encode_sequences(tar_tokenizer, tar_length, train[:, idx_tar])
trainY = encode_output(trainY, tar_vocab_size)

# Prepare test data
testX = encode_sequences(src_tokenizer, src_length, test[:, idx_src])
testY = encode_sequences(tar_tokenizer, tar_length, test[:, idx_tar])
testY = encode_output(testY, tar_vocab_size)
# Out:
# Target (English) Vocabulary Size: 2099
# Target (English) Max Length: 5
# Source (French) Vocabulary Size: 4039
# Source (French) Max Length: 12

# %%
def create_model(src_vocab, tar_vocab, src_timesteps, tar_timesteps, n_units):
    # Create the model
    model = Sequential()
    model.add(Embedding(src_vocab, n_units, input_length=src_timesteps, mask_zero=True))
    model.add(LSTM(n_units))
    model.add(RepeatVector(tar_timesteps))
    model.add(LSTM(n_units, return_sequences=True))
    model.add(TimeDistributed(Dense(tar_vocab, activation='softmax')))
    return model

# Create model
model = create_model(src_vocab_size, tar_vocab_size, src_length, tar_length, 256)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

history = model.fit(trainX,
          trainY,
          epochs=50,
          batch_size=64,
          validation_split=0.1,
          verbose=1,
          callbacks=[
                        EarlyStopping(
                        monitor='val_loss',
                        patience=10,
                        restore_best_weights=True
                    )
            ])
# Out:
# Epoch 1/50
# 127/127 [==============================] - 24s 148ms/step - loss: 4.3502 - accuracy: 0.4104 - val_loss: 3.4971 - val_accuracy: 0.4407
# Epoch 2/50
# 127/127 [==============================] - 17s 135ms/step - loss: 3.3229 - accuracy: 0.4538 - val_loss: 3.2887 - val_accuracy: 0.4524
# Epoch 3/50
# 127/127 [==============================] - 18s 144ms/step - loss: 3.1054 - accuracy: 0.4724 - val_loss: 3.1050 - val_accuracy: 0.4820
# Epoch 4/50
# 127/127 [==============================] - 17s 136ms/step - loss: 2.9167 - accuracy: 0.4894 - val_loss: 3.0118 - val_accuracy: 0.4967
# Epoch 5/50
# 127/127 [==============================] - 17s 136ms/step - loss: 2.7886 - accuracy: 0.5027 - val_loss: 2.9205 - val_accuracy: 0.5029
# Epoch 6/50
# 127/127 [==============================] - 18s 144ms/step - loss: 2.6630 - accuracy: 0.5196 - val_loss: 2.8280 - val_accuracy: 0.5238
# Epoch 7/50
# 127/127 [==============================] - 17s 135ms/step - loss: 2.5138 - accuracy: 0.5428 - val_loss: 2.6986 - val_accuracy: 0.5433
# Epoch 8/50
# 127/127 [==============================] - 17s 136ms/step - loss: 2.3700 - accuracy: 0.5647 - val_loss: 2.6024 - val_accuracy: 0.5698
# Epoch 9/50
# 127/127 [==============================] - 18s 138ms/step - loss: 2.2299 - accuracy: 0.5880 - val_loss: 2.4914 - val_accuracy: 0.5831
# Epoch 10/50
# 127/127 [==============================] - 17s 134ms/step - loss: 2.0830 - accuracy: 0.6093 - val_loss: 2.3850 - val_accuracy: 0.6053
# Epoch 11/50
# 127/127 [==============================] - 17s 138ms/step - loss: 1.9479 - accuracy: 0.6268 - val_loss: 2.3093 - val_accuracy: 0.6113
# Epoch 12/50
# 127/127 [==============================] - 17s 137ms/step - loss: 1.8250 - accuracy: 0.6425 - val_loss: 2.2413 - val_accuracy: 0.6244
# Epoch 13/50
# 127/127 [==============================] - 17s 134ms/step - loss: 1.7070 - accuracy: 0.6573 - val_loss: 2.1749 - val_accuracy: 0.6327
# Epoch 14/50
# 127/127 [==============================] - 19s 147ms/step - loss: 1.5944 - accuracy: 0.6740 - val_loss: 2.1230 - val_accuracy: 0.6411
# Epoch 15/50
# 127/127 [==============================] - 17s 136ms/step - loss: 1.4919 - accuracy: 0.6875 - val_loss: 2.0835 - val_accuracy: 0.6471
# Epoch 16/50
# 127/127 [==============================] - 17s 137ms/step - loss: 1.3965 - accuracy: 0.7024 - val_loss: 2.0435 - val_accuracy: 0.6547
# Epoch 17/50
# 127/127 [==============================] - 18s 144ms/step - loss: 1.3032 - accuracy: 0.7156 - val_loss: 2.0094 - val_accuracy: 0.6640
# Epoch 18/50
# 127/127 [==============================] - 17s 136ms/step - loss: 1.2155 - accuracy: 0.7287 - val_loss: 1.9856 - val_accuracy: 0.6722
# Epoch 19/50
# 127/127 [==============================] - 18s 139ms/step - loss: 1.1312 - accuracy: 0.7454 - val_loss: 1.9514 - val_accuracy: 0.6798
# Epoch 20/50
# 127/127 [==============================] - 18s 142ms/step - loss: 1.0516 - accuracy: 0.7609 - val_loss: 1.9262 - val_accuracy: 0.6816
# Epoch 21/50
# 127/127 [==============================] - 18s 139ms/step - loss: 0.9773 - accuracy: 0.7778 - val_loss: 1.9032 - val_accuracy: 0.6933
# Epoch 22/50
# 127/127 [==============================] - 18s 145ms/step - loss: 0.9038 - accuracy: 0.7961 - val_loss: 1.8793 - val_accuracy: 0.6927
# Epoch 23/50
# 127/127 [==============================] - 17s 137ms/step - loss: 0.8365 - accuracy: 0.8109 - val_loss: 1.8549 - val_accuracy: 0.7018
# Epoch 24/50
# 127/127 [==============================] - 18s 138ms/step - loss: 0.7723 - accuracy: 0.8245 - val_loss: 1.8516 - val_accuracy: 0.7089
# Epoch 25/50
# 127/127 [==============================] - 18s 143ms/step - loss: 0.7113 - accuracy: 0.8405 - val_loss: 1.8252 - val_accuracy: 0.7138
# Epoch 26/50
# 127/127 [==============================] - 17s 136ms/step - loss: 0.6548 - accuracy: 0.8534 - val_loss: 1.8090 - val_accuracy: 0.7202
# Epoch 27/50
# 127/127 [==============================] - 18s 142ms/step - loss: 0.6005 - accuracy: 0.8669 - val_loss: 1.7901 - val_accuracy: 0.7224
# Epoch 28/50
# 127/127 [==============================] - 18s 138ms/step - loss: 0.5525 - accuracy: 0.8781 - val_loss: 1.7997 - val_accuracy: 0.7280
# Epoch 29/50
# 127/127 [==============================] - 18s 138ms/step - loss: 0.5075 - accuracy: 0.8889 - val_loss: 1.7921 - val_accuracy: 0.7282
# Epoch 30/50
# 127/127 [==============================] - 18s 145ms/step - loss: 0.4675 - accuracy: 0.8975 - val_loss: 1.7724 - val_accuracy: 0.7340
# Epoch 31/50
# 127/127 [==============================] - 17s 137ms/step - loss: 0.4314 - accuracy: 0.9061 - val_loss: 1.7871 - val_accuracy: 0.7316
# Epoch 32/50
# 127/127 [==============================] - 17s 137ms/step - loss: 0.3976 - accuracy: 0.9141 - val_loss: 1.7758 - val_accuracy: 0.7329
# Epoch 33/50
# 127/127 [==============================] - 18s 143ms/step - loss: 0.3621 - accuracy: 0.9229 - val_loss: 1.7749 - val_accuracy: 0.7347
# Epoch 34/50
# 127/127 [==============================] - 17s 137ms/step - loss: 0.3304 - accuracy: 0.9282 - val_loss: 1.7629 - val_accuracy: 0.7384
# Epoch 35/50
# 127/127 [==============================] - 19s 148ms/step - loss: 0.3047 - accuracy: 0.9336 - val_loss: 1.7630 - val_accuracy: 0.7404
# Epoch 36/50
# 127/127 [==============================] - 17s 135ms/step - loss: 0.2798 - accuracy: 0.9391 - val_loss: 1.7605 - val_accuracy: 0.7422
# Epoch 37/50
# 127/127 [==============================] - 17s 136ms/step - loss: 0.2584 - accuracy: 0.9437 - val_loss: 1.7611 - val_accuracy: 0.7436
# Epoch 38/50
# 127/127 [==============================] - 18s 145ms/step - loss: 0.2384 - accuracy: 0.9467 - val_loss: 1.7672 - val_accuracy: 0.7451
# Epoch 39/50
# 127/127 [==============================] - 17s 136ms/step - loss: 0.2216 - accuracy: 0.9501 - val_loss: 1.7757 - val_accuracy: 0.7453
# Epoch 40/50
# 127/127 [==============================] - 17s 137ms/step - loss: 0.2067 - accuracy: 0.9519 - val_loss: 1.7887 - val_accuracy: 0.7440
# Epoch 41/50
# 127/127 [==============================] - 18s 141ms/step - loss: 0.1922 - accuracy: 0.9545 - val_loss: 1.7817 - val_accuracy: 0.7462
# Epoch 42/50
# 127/127 [==============================] - 17s 135ms/step - loss: 0.1789 - accuracy: 0.9576 - val_loss: 1.7881 - val_accuracy: 0.7482
# Epoch 43/50
# 127/127 [==============================] - 18s 142ms/step - loss: 0.1676 - accuracy: 0.9584 - val_loss: 1.8024 - val_accuracy: 0.7462
# Epoch 44/50
# 127/127 [==============================] - 18s 138ms/step - loss: 0.1574 - accuracy: 0.9602 - val_loss: 1.7937 - val_accuracy: 0.7489
# Epoch 45/50
# 127/127 [==============================] - 17s 137ms/step - loss: 0.1479 - accuracy: 0.9604 - val_loss: 1.8069 - val_accuracy: 0.7489
# Epoch 46/50
# 127/127 [==============================] - 18s 144ms/step - loss: 0.1408 - accuracy: 0.9623 - val_loss: 1.8073 - val_accuracy: 0.7469

# %%
pd.DataFrame(history.history).plot()
plt.title("Loss")
plt.show()

# %%
def word_for_id(integer, tokenizer):
    # map an integer to a word
    for word, index in tokenizer.word_index.items():
        if index == integer:
            return word
    return None

def predict_seq(model, tokenizer, source):
    # generate target from a source sequence
    prediction = model.predict(source, verbose=0)[0]
    integers = [np.argmax(vector) for vector in prediction]
    target = list()
    for i in integers:
        word = word_for_id(i, tokenizer)
        if word is None:
            break
        target.append(word)
    return ' '.join(target)

def compare_prediction(model, tokenizer, sources, raw_dataset, limit=20):
    # evaluate a model
    actual, predicted = [], []
    src = f'{source_str.upper()} (SOURCE)'
    tgt = f'{target_str.upper()} (TARGET)'
    pred = f'AUTOMATIC TRANSLATION IN {target_str.upper()}'
    print(f'{src:30} {tgt:25} {pred}\n')

    for i, source in enumerate(sources): # translate encoded source text
        source = source.reshape((1, source.shape[0]))
        translation = predict_seq(model, tar_tokenizer, source)
        raw_target, raw_src = raw_dataset[i]
        print(f'{raw_src:30} {raw_target:25} {translation}')
        if i >= limit: # Display some of the result
            break

# test on some training sequences
print('### Result on the Training Set ###')
compare_prediction(model, tar_tokenizer, trainX, train)

# test on some test sequences
print('\n\n### Result on the Test Set ###')
compare_prediction(model, tar_tokenizer, testX, test)
# Out:
# ### Result on the Training Set ###
# FRENCH (SOURCE)                ENGLISH (TARGET)          AUTOMATIC TRANSLATION IN ENGLISH
#
# nous en savons assez           we know enough            we know enough
# garde ton sang froid           stay calm                 stay calm
# je ne pleurerai pas            i won t cry               i won t cry
# je ne suis pas contente        i m not happy             i m not happy
# moi je veux ça                 i want that               i want that
# j étais tellement heureuse     i was so happy            i was so happy
# j aime le printemps            i like spring             i like spring
# c est mon garçon               that s my boy             that s my dog
# mille mercis                   many thanks               thanks a
# quelle horreur                 how horrible              how horrible
# soyez satisfaites              be content                be content
# toi décide                     you decide                you decide
# je m en suis remis             i recovered               i recovered
# ce sont les affaires           it s business             it s business
# je dois m en aller             i need to go              i need to go
# sommes nous prêtes             are we ready              are we ready
# arrêtez de crier               stop shouting             stop shouting
# je lis souvent                 i often read              i often apologize
# les plantes croissent          plants grow               plants grow
# il m a fallu le faire          i had to do it            i had to do it
# nous éclatâmes de rire         we broke up               we broke up
#
#
# ### Result on the Test Set ###
# FRENCH (SOURCE)                ENGLISH (TARGET)          AUTOMATIC TRANSLATION IN ENGLISH
#
# ils ont abandonné              they gave up              they gave up
# rappelle moi                   call me back              ask me
# je veux essayer                i want to try             i want to it
# ça fonctionne bien             it works well             it was good
# grimpe dans la camionnette     get in the van            get in the van
# je suis mince                  i m thin                  i m sure
# elle semble riche              she seems rich            she looks angry
# ça me gave                     this annoys me            it gets break
# c était long                   it was long               how
# c était un mensonge            it was a lie              that was a lie
# conduis toi en homme           act like a man            see a lie
# laissez moi m en occuper       leave it to me            let me me
# puis je manger ceci            may i eat this            can i see this
# devine                         make a guess              seal the drowning
# je ne suis pas jolie           i m not pretty            i m not alone
# demande à quiconque            ask anyone                their arguing
# venez nous rejoindre           come join us              come us alone
# vous ennuyez vous              are you bored             you you love
# je ne viendrai pas             i won t come              i can t get it
# c est un voleur                he is a thief             this is a fake
# bien joué                      well done                 good job

# %%
# Using BELU

def bleu_score(model, tokenizer, sources, raw_dataset):
    # Get the bleu score of a model
    actual, predicted = [], []
    for i, source in enumerate(sources):
        # translate encoded source text
        source = source.reshape((1, source.shape[0]))
        translation = predict_seq(model, tar_tokenizer, source)
        raw_target, raw_src = raw_dataset[i]
        actual.append([raw_target.split()])
        predicted.append(translation.split())

    bleu_dic = {}
    bleu_dic['1-grams'] = corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0))
    bleu_dic['1-2-grams'] = corpus_bleu(actual, predicted, weights=(0.5, 0.5, 0, 0))
    bleu_dic['1-3-grams'] = corpus_bleu(actual, predicted, weights=(0.3, 0.3, 0.3, 0))
    bleu_dic['1-4-grams'] = corpus_bleu(actual, predicted, weights=(0.25, 0.25, 0.25, 0.25))

    return bleu_dic

# Compute the BLEU Score
bleu_train = bleu_score(model, tar_tokenizer, trainX, train)
bleu_test = bleu_score(model, tar_tokenizer, testX, test)
plt.bar(x = bleu_train.keys(), height = bleu_train.values())
plt.title("BLEU Score with the training set")
plt.ylim((0,1))
# Out:
# (0.0, 1.0)

# %%
plt.bar(x = bleu_test.keys(), height = bleu_test.values())
plt.title("BLEU Score with the test set")
plt.ylim((0,1))
plt.show()
